# %% [markdown]
# # Script to Get IDs and Summaries

# %% [markdown]
# ## Get ID's

# %%
# Imports
from Bio import Entrez
import csv
import time

# Define max_samples
max_samples = 100

# Define email
Entrez.email = "vela.vela.luis@gmail.com" #"karsten.leonhardt@posteo.de"

# Perform search - get handle
handle = Entrez.esearch(db="gds", term="GSE[ETYP] AND Homo[Organism]", usehistory="y", retmax = max_samples)

# Read results
record = Entrez.read(handle)

# Get idlist
idlist = record['IdList']

# Count entries
found_count = int(record['Count'])
read_count = len(idlist)

# Echo results
print('Total number of FOUND entries: ' + str(found_count))
print('Total number of READ  entries: ' + str(read_count))

# Close handle
handle.close()
# Out:
# Total number of FOUND entries: 46584
# Total number of READ  entries: 100

# %% [markdown]
# ## Get Summaries

# %%
# Set name of file
filename = 'summaries.csv'

# Open csv-target file
with open(filename, 'w') as opened_file:

    # write with writer
    csvwriter = csv.writer(opened_file)

    # Set fieldnames
#     fieldnames = ['Item', 'Id', 'Accession', 'GDS', 'title', 
#           'summary', 'GPL', 'GSE', 'taxon', 'entryType', 'gdsType', 
#           'ptechType', 'valType', 'SSInfo', 'subsetInfo', 'PDAT', 
#           'suppFile', 'Samples', 'Relations', 'ExtRelations', 
#           'n_samples', 'SeriesTitle', 'PlatformTitle', 'PlatformTaxa', 
#           'SamplesTaxa', 'PubMedIds', 'Projects', 'FTPLink', 'GEO2R']
    fieldnames = ['Id', 'Accession', 'title', 'summary', 'taxon']
        
    # Print fildnames
    csvwriter.writerow(fieldnames)

    # Begin retrieval
    for i, e_id in enumerate(idlist):
    
        # Echo info
        print("Going to download record: {:10.0f} ({:5.1f}%)".format(int(e_id), (i+1)/read_count*100))
    
        # Avoid HTTP error (max 3 queries per second ?)
        if (i%3==0): time.sleep(1)
        
        # Get Summary
        handle = Entrez.esummary(db="gds", id=e_id)
    
        # Read handle
        data = Entrez.read(handle)

        # Define list for things to print
        list_to_print = list()

        # Iterate over fieldnames
        for name in fieldnames:
            list_to_print.append(data[0][name])

        # Print the line
        csvwriter.writerow(list_to_print)
        
        # Close handle
        handle.close()
# Out:
# Going to download record:  200112120 (  1.0%)
# Going to download record:  200117735 (  2.0%)
# Going to download record:  200117734 (  3.0%)
# Going to download record:  200128119 (  4.0%)
# Going to download record:  200126367 (  5.0%)
# Going to download record:  200128077 (  6.0%)
# Going to download record:  200126109 (  7.0%)
# Going to download record:  200106774 (  8.0%)
# Going to download record:  200125561 (  9.0%)
# Going to download record:  200117301 ( 10.0%)
# Going to download record:  200117311 ( 11.0%)
# Going to download record:  200112164 ( 12.0%)
# Going to download record:  200120993 ( 13.0%)
# Going to download record:  200124453 ( 14.0%)
# Going to download record:  200106592 ( 15.0%)
# Going to download record:  200115197 ( 16.0%)
# Going to download record:  200115196 ( 17.0%)
# Going to download record:  200116984 ( 18.0%)
# Going to download record:  200107387 ( 19.0%)
# Going to download record:  200111073 ( 20.0%)
# Going to download record:  200117145 ( 21.0%)
# Going to download record:  200128079 ( 22.0%)
# Going to download record:  200128078 ( 23.0%)
# Going to download record:  200128068 ( 24.0%)
# Going to download record:  200128067 ( 25.0%)
# Going to download record:  200128066 ( 26.0%)
# Going to download record:  200128064 ( 27.0%)
# Going to download record:  200128040 ( 28.0%)
# Going to download record:  200096060 ( 29.0%)
# Going to download record:  200118527 ( 30.0%)
# Going to download record:  200111636 ( 31.0%)
# Going to download record:  200111422 ( 32.0%)
# Going to download record:  200111665 ( 33.0%)
# Going to download record:  200111567 ( 34.0%)
# Going to download record:  200124025 ( 35.0%)
# Going to download record:  200125328 ( 36.0%)
# Going to download record:  200072048 ( 37.0%)
# Going to download record:  200125932 ( 38.0%)
# Going to download record:  200124757 ( 39.0%)
# Going to download record:  200090963 ( 40.0%)
# Going to download record:  200128021 ( 41.0%)
# Going to download record:  200128004 ( 42.0%)
# Going to download record:  200112969 ( 43.0%)
# Going to download record:  200126419 ( 44.0%)
# Going to download record:  200127905 ( 45.0%)
# Going to download record:  200127967 ( 46.0%)
# Going to download record:  200127962 ( 47.0%)
# Going to download record:  200127952 ( 48.0%)
# Going to download record:  200123055 ( 49.0%)
# Going to download record:  200120663 ( 50.0%)
# Going to download record:  200114974 ( 51.0%)
# Going to download record:  200125370 ( 52.0%)
# Going to download record:  200125602 ( 53.0%)
# Going to download record:  200126882 ( 54.0%)
# Going to download record:  200122672 ( 55.0%)
# Going to download record:  200112145 ( 56.0%)
# Going to download record:  200111484 ( 57.0%)
# Going to download record:  200111483 ( 58.0%)
# Going to download record:  200111482 ( 59.0%)
# Going to download record:  200111481 ( 60.0%)
# Going to download record:  200111480 ( 61.0%)
# Going to download record:  200113629 ( 62.0%)
# Going to download record:  200122056 ( 63.0%)
# Going to download record:  200121981 ( 64.0%)
# Going to download record:  200124075 ( 65.0%)
# Going to download record:  200124073 ( 66.0%)
# Going to download record:  200124070 ( 67.0%)
# Going to download record:  200124031 ( 68.0%)
# Going to download record:  200123532 ( 69.0%)
# Going to download record:  200117086 ( 70.0%)
# Going to download record:  200120574 ( 71.0%)
# Going to download record:  200127849 ( 72.0%)
# Going to download record:  200127848 ( 73.0%)
# Going to download record:  200127837 ( 74.0%)
# Going to download record:  200127836 ( 75.0%)
# Going to download record:  200127835 ( 76.0%)
# Going to download record:  200126252 ( 77.0%)
# Going to download record:  200127888 ( 78.0%)
# Going to download record:  200127873 ( 79.0%)
# Going to download record:  200127871 ( 80.0%)
# Going to download record:  200122588 ( 81.0%)
# Going to download record:  200125013 ( 82.0%)
# Going to download record:  200122439 ( 83.0%)
# Going to download record:  200122437 ( 84.0%)
# Going to download record:  200096064 ( 85.0%)
# Going to download record:  200100508 ( 86.0%)
# Going to download record:  200112137 ( 87.0%)
# Going to download record:  200045515 ( 88.0%)
# Going to download record:  200099127 ( 89.0%)
# Going to download record:  200124818 ( 90.0%)
# Going to download record:  200127829 ( 91.0%)
# Going to download record:  200127828 ( 92.0%)
# Going to download record:  200127824 ( 93.0%)
# Going to download record:  200127792 ( 94.0%)
# Going to download record:  200127791 ( 95.0%)
# Going to download record:  200127770 ( 96.0%)
# Going to download record:  200127763 ( 97.0%)
# Going to download record:  200105109 ( 98.0%)
# Going to download record:  200103404 ( 99.0%)
# Going to download record:  200103431 (100.0%)
